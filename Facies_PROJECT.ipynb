# %% [markdown]
# #Ayush Pratap Singh
# #21JE0213
# #ayushps0712@gmail.com

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_excel('Volve_production_data.xlsx',sheet_name='Daily Production Data')

# %%
df.shape
# Out:
# (15634, 24)

# %%
df.head()
# Out:
#      DATEPRD WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# 0 2014-04-07  NO 15/9-F-1 C                7405         15/9-F-1 C
# 1 2014-04-08  NO 15/9-F-1 C                7405         15/9-F-1 C
# 2 2014-04-09  NO 15/9-F-1 C                7405         15/9-F-1 C
# 3 2014-04-10  NO 15/9-F-1 C                7405         15/9-F-1 C
# 4 2014-04-11  NO 15/9-F-1 C                7405         15/9-F-1 C
#
#    NPD_FIELD_CODE NPD_FIELD_NAME  NPD_FACILITY_CODE NPD_FACILITY_NAME  \
# 0         3420717          VOLVE             369304    MÆRSK INSPIRER
# 1         3420717          VOLVE             369304    MÆRSK INSPIRER
# 2         3420717          VOLVE             369304    MÆRSK INSPIRER
# 3         3420717          VOLVE             369304    MÆRSK INSPIRER
# 4         3420717          VOLVE             369304    MÆRSK INSPIRER
#
#    ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  ...  AVG_CHOKE_UOM  AVG_WHP_P  \
# 0            0.0                0.00000  ...              %    0.00000
# 1            0.0                    NaN  ...              %    0.00000
# 2            0.0                    NaN  ...              %    0.00000
# 3            0.0                    NaN  ...              %    0.00000
# 4            0.0              310.37614  ...              %   33.09788
#
#    AVG_WHT_P  DP_CHOKE_SIZE BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0    0.00000        0.00000          0.0           0.0           0.0
# 1    0.00000        0.00000          0.0           0.0           0.0
# 2    0.00000        0.00000          0.0           0.0           0.0
# 3    0.00000        0.00000          0.0           0.0           0.0
# 4   10.47992       33.07195          0.0           0.0           0.0
#
#    BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0          NaN  production         WI
# 1          NaN  production         OP
# 2          NaN  production         OP
# 3          NaN  production         OP
# 4          NaN  production         OP
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['DATEPRD', 'WELL_BORE_CODE', 'NPD_WELL_BORE_CODE', 'NPD_WELL_BORE_NAME',
#        'NPD_FIELD_CODE', 'NPD_FIELD_NAME', 'NPD_FACILITY_CODE',
#        'NPD_FACILITY_NAME', 'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE',
#        'AVG_DOWNHOLE_TEMPERATURE', 'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS',
#        'AVG_CHOKE_SIZE_P', 'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P',
#        'DP_CHOKE_SIZE', 'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL',
#        'BORE_WI_VOL', 'FLOW_KIND', 'WELL_TYPE'],
#       dtype='object')

# %%
df["NPD_WELL_BORE_NAME"].unique()
# Out:
# array(['15/9-F-1 C', '15/9-F-11', '15/9-F-12', '15/9-F-14', '15/9-F-15 D',
#        '15/9-F-4', '15/9-F-5'], dtype=object)

# %%
df=df[["DATEPRD",'NPD_WELL_BORE_NAME','ON_STREAM_HRS','AVG_DOWNHOLE_PRESSURE','AVG_DOWNHOLE_TEMPERATURE','BORE_OIL_VOL','BORE_GAS_VOL','BORE_WAT_VOL','FLOW_KIND']]

# %%
WellA=df[df.NPD_WELL_BORE_NAME=="15/9-F-1 C"]

# %%
WellA.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07         15/9-F-1 C            0.0                0.00000
# 1 2014-04-08         15/9-F-1 C            0.0                    NaN
# 2 2014-04-09         15/9-F-1 C            0.0                    NaN
# 3 2014-04-10         15/9-F-1 C            0.0                    NaN
# 4 2014-04-11         15/9-F-1 C            0.0              310.37614
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0                   0.00000           0.0           0.0           0.0
# 1                       NaN           0.0           0.0           0.0
# 2                       NaN           0.0           0.0           0.0
# 3                       NaN           0.0           0.0           0.0
# 4                  96.87589           0.0           0.0           0.0
#
#     FLOW_KIND
# 0  production
# 1  production
# 2  production
# 3  production
# 4  production

# %%
WellA.count()
# Out:
# DATEPRD                     746
# NPD_WELL_BORE_NAME          746
# ON_STREAM_HRS               746
# AVG_DOWNHOLE_PRESSURE       743
# AVG_DOWNHOLE_TEMPERATURE    743
# BORE_OIL_VOL                746
# BORE_GAS_VOL                746
# BORE_WAT_VOL                746
# FLOW_KIND                   746
# dtype: int64

# %%
WellA1=WellA.dropna()

# %%
WellA1.count()
# Out:
# DATEPRD                     743
# NPD_WELL_BORE_NAME          743
# ON_STREAM_HRS               743
# AVG_DOWNHOLE_PRESSURE       743
# AVG_DOWNHOLE_TEMPERATURE    743
# BORE_OIL_VOL                743
# BORE_GAS_VOL                743
# BORE_WAT_VOL                743
# FLOW_KIND                   743
# dtype: int64

# %%
WellA1.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07         15/9-F-1 C            0.0                0.00000
# 4 2014-04-11         15/9-F-1 C            0.0              310.37614
# 5 2014-04-12         15/9-F-1 C            0.0              303.50078
# 6 2014-04-13         15/9-F-1 C            0.0              303.53481
# 7 2014-04-14         15/9-F-1 C            0.0              303.78228
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0                   0.00000           0.0           0.0           0.0
# 4                  96.87589           0.0           0.0           0.0
# 5                  96.92339           0.0           0.0           0.0
# 6                  96.95885           0.0           0.0           0.0
# 7                  96.96873           0.0           0.0           0.0
#
#     FLOW_KIND
# 0  production
# 4  production
# 5  production
# 6  production
# 7  production

# %%
productionData=df[df.FLOW_KIND=="production"]

# %%
productionData.count()
# Out:
# DATEPRD                     9161
# NPD_WELL_BORE_NAME          9161
# ON_STREAM_HRS               9161
# AVG_DOWNHOLE_PRESSURE       8980
# AVG_DOWNHOLE_TEMPERATURE    8980
# BORE_OIL_VOL                9161
# BORE_GAS_VOL                9161
# BORE_WAT_VOL                9161
# FLOW_KIND                   9161
# dtype: int64

# %%
productionData.groupby("NPD_WELL_BORE_NAME").sum()
# Out:
# <ipython-input-164-16737e038c16>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   productionData.groupby("NPD_WELL_BORE_NAME").sum()
#                     ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# NPD_WELL_BORE_NAME
# 15/9-F-1 C             9983.53315          183272.862798
# 15/9-F-11             26006.21614          271162.380252
# 15/9-F-12             65204.06928          246223.670095
# 15/9-F-14             62773.67519          710877.683553
# 15/9-F-15 D           17824.83278          221062.144637
# 15/9-F-5               2973.32502               0.000000
#
#                     AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  \
# NPD_WELL_BORE_NAME
# 15/9-F-1 C                      77959.493534     177709.33  2.644092e+07
# 15/9-F-11                      120921.733869    1147849.10  1.743105e+08
# 15/9-F-12                      101540.832797    4579609.55  6.675423e+08
# 15/9-F-14                      290158.064528    3942233.39  5.780095e+08
# 15/9-F-15 D                    102343.339583     148518.56  2.250535e+07
# 15/9-F-5                            0.000000      41160.68  6.561826e+06
#
#                     BORE_WAT_VOL
# NPD_WELL_BORE_NAME
# 15/9-F-1 C             207302.39
# 15/9-F-11             1090806.27
# 15/9-F-12             6833320.37
# 15/9-F-14             7121249.74
# 15/9-F-15 D             52366.40
# 15/9-F-5                13533.18

# %%
fig, ax = plt.subplots(figsize = (20,10))

productionData.groupby("NPD_WELL_BORE_NAME").sum().plot.pie(ax = ax, y = "BORE_OIL_VOL", figsize = (20,10), fontsize = 13)

ax.set_ylabel("")

ax.legend(fontsize = 11, loc = 3)

plt.show()
# Out:
# <ipython-input-165-3b0dc67ab74f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   productionData.groupby("NPD_WELL_BORE_NAME").sum().plot.pie(ax = ax, y = "BORE_OIL_VOL", figsize = (20,10), fontsize = 13)

# %%
plt.figure(figsize=(20,10))
plt.hist(WellA1.AVG_DOWNHOLE_PRESSURE)
plt.xlabel("AVG_DOWNHOLE_PRESSURE",fontweight="bold",fontsize=20)
plt.ylabel("Frequency",fontweight="bold",fontsize=20)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.jointplot(x="BORE_OIL_VOL",y="AVG_DOWNHOLE_PRESSURE",data=WellA1)

# %%
#Load data
well_13 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 13',index_col=0)
well_14 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 14')
well_15 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 15')

# %%
data = pd.concat([well_14, well_15], axis=0)
data['Well'] = data['Well'].astype('category')
data['RT_log'] = np.log10(data.RT) #For Visualization
data
# Out:
#        Depth Well       GR      RT    RHOB    NPHI Facies    RT_log
# 0     3178.5   14  50.2190  0.5888  2.3296  0.3657     SH -0.230032
# 1     3179.0   14  47.2468  0.7768  2.3170  0.3776     UN -0.109691
# 2     3179.5   14  49.5247  1.0707  2.2960  0.5390     SH  0.029668
# 3     3180.0   14  44.9124  1.4460  2.2514  0.5482     UN  0.160168
# 4     3180.5   14  47.0048  0.9542  2.2733  0.5076     UN -0.020361
# ...      ...  ...      ...     ...     ...     ...    ...       ...
# 1154  4083.5   15  59.7060  1.7590  2.4851  0.1416     CB  0.245266
# 1155  4084.0   15  58.4170  1.6510  2.4860  0.1416     CB  0.217747
# 1156  4084.5   15  57.4990  1.5970  2.5311  0.1527     CB  0.203305
# 1157  4085.0   15  56.7850  1.4820  2.4731  0.1785     CB  0.170848
# 1158  4085.5   15  61.7220  1.4350  2.4920  0.1566     CB  0.156852
#
# [3241 rows x 8 columns]

# %%
sns.pairplot(data.drop(["Depth","Well"],axis=1),hue="Facies")

# %%
data.head()
# Out:
#     Depth Well       GR      RT    RHOB    NPHI Facies    RT_log
# 0  3178.5   14  50.2190  0.5888  2.3296  0.3657     SH -0.230032
# 1  3179.0   14  47.2468  0.7768  2.3170  0.3776     UN -0.109691
# 2  3179.5   14  49.5247  1.0707  2.2960  0.5390     SH  0.029668
# 3  3180.0   14  44.9124  1.4460  2.2514  0.5482     UN  0.160168
# 4  3180.5   14  47.0048  0.9542  2.2733  0.5076     UN -0.020361

# %%
data.Facies.unique()
# Out:
# array(['SH', 'UN', 'SS', 'CB'], dtype=object)

# %%
data.Facies.value_counts()
# Out:
# CB    1249
# SS     997
# SH     871
# UN     124
# Name: Facies, dtype: int64

# %%
data["Facies"].replace("SH",1,inplace=True)
data["Facies"].replace("UN",2,inplace=True)
data["Facies"].replace("SS",3,inplace=True)
data["Facies"].replace("CB",4,inplace=True)

# %%
data.head()
# Out:
#     Depth Well       GR      RT    RHOB    NPHI  Facies    RT_log
# 0  3178.5   14  50.2190  0.5888  2.3296  0.3657       1 -0.230032
# 1  3179.0   14  47.2468  0.7768  2.3170  0.3776       2 -0.109691
# 2  3179.5   14  49.5247  1.0707  2.2960  0.5390       1  0.029668
# 3  3180.0   14  44.9124  1.4460  2.2514  0.5482       2  0.160168
# 4  3180.5   14  47.0048  0.9542  2.2733  0.5076       2 -0.020361

# %%
data["Density_porosity"]=(data["RHOB"]-2.71)/(1-2.71)
data.head()
# Out:
#     Depth Well       GR      RT    RHOB    NPHI  Facies    RT_log  \
# 0  3178.5   14  50.2190  0.5888  2.3296  0.3657       1 -0.230032
# 1  3179.0   14  47.2468  0.7768  2.3170  0.3776       2 -0.109691
# 2  3179.5   14  49.5247  1.0707  2.2960  0.5390       1  0.029668
# 3  3180.0   14  44.9124  1.4460  2.2514  0.5482       2  0.160168
# 4  3180.5   14  47.0048  0.9542  2.2733  0.5076       2 -0.020361
#
#    Density_porosity
# 0          0.222456
# 1          0.229825
# 2          0.242105
# 3          0.268187
# 4          0.255380

# %%
Well_14=data[data.Well==14]

# %%
Logs=["GR",'RT','NPHI','RHOB']
facies = ['SH', 'UN', 'SS', 'CB']
colors = ['green', 'red','blue','brown']
fig,ax=plt.subplots(1,5,figsize=(12,16))
ax[0].set_ylabel("Depth",fontweight="bold",fontsize=15)

for i in range(len(Logs)):
    if Logs[i]=="RT" or Logs[i]=="GR":
        ax[i].semilogx(Well_14[Logs[i]],Well_14.Depth,label=Logs[i],color=colors[i],lw=0.8)
    else:
        ax[i].plot(Well_14[Logs[i]],Well_14.Depth,label=Logs[i],color=colors[i],lw=0.8)
    ax[i].set_xlabel(Logs[i],fontweight="bold",fontsize=15)
    ax[i].set_xlim(Well_14[Logs[i]].min(),Well_14[Logs[i]].max())
    ax[i].grid(True)

ax[4].plot(Well_14.NPHI,Well_14.Depth,color="blue",lw=0.5,label="NPHI")
ax[4].set_xlim(Well_14.NPHI.max(),Well_14.NPHI.min())
ax2=ax[4].twiny()
ax2.plot(Well_14.Density_porosity,well_14.Depth,color="red",lw=0.5,label="DensityPorosity")
fig.legend()
ax[4].grid()

# %%
data.columns
# Out:
# Index(['Depth', 'Well', 'GR', 'RT', 'RHOB', 'NPHI', 'Facies', 'RT_log',
#        'Density_porosity'],
#       dtype='object')

# %%
data.head()
x=data.drop(['Depth','Well','Facies','RT_log','Density_porosity','Facies'],axis=1)
y=data["Facies"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape
x_test.shape
# Out:
# (973, 4)

# %%
x_train.hist()
# Out:
# array([[<Axes: title={'center': 'GR'}>, <Axes: title={'center': 'RT'}>],
#        [<Axes: title={'center': 'RHOB'}>,
#         <Axes: title={'center': 'NPHI'}>]], dtype=object)

# %%
data.head()
# Out:
#     Depth Well       GR      RT    RHOB    NPHI  Facies    RT_log  \
# 0  3178.5   14  50.2190  0.5888  2.3296  0.3657       1 -0.230032
# 1  3179.0   14  47.2468  0.7768  2.3170  0.3776       2 -0.109691
# 2  3179.5   14  49.5247  1.0707  2.2960  0.5390       1  0.029668
# 3  3180.0   14  44.9124  1.4460  2.2514  0.5482       2  0.160168
# 4  3180.5   14  47.0048  0.9542  2.2733  0.5076       2 -0.020361
#
#    Density_porosity
# 0          0.222456
# 1          0.229825
# 2          0.242105
# 3          0.268187
# 4          0.255380

# %%
data.describe()
# Out:
#              Depth           GR           RT         RHOB         NPHI  \
# count  3241.000000  3241.000000  3241.000000  3241.000000  3241.000000
# mean   3733.609380    51.379917     4.292569     2.432688     0.207456
# std     265.253354    57.700965    14.524740     0.147662     0.104241
# min    3178.500000     3.655000     0.094000     1.805100     0.013500
# 25%    3542.000000    17.433000     1.014000     2.311000     0.133600
# 50%    3747.500000    34.083600     1.864900     2.459000     0.187900
# 75%    3950.500000    71.846000     3.697700     2.550000     0.267500
# max    4220.500000  1567.590000   461.170000     3.149300     0.853200
#
#             Facies       RT_log  Density_porosity
# count  3241.000000  3241.000000       3241.000000
# mean      2.809627     0.278370          0.162171
# std       1.209471     0.487116          0.086352
# min       1.000000    -1.026872         -0.256901
# 25%       1.000000     0.006038          0.093567
# 50%       3.000000     0.270656          0.146784
# 75%       4.000000     0.567932          0.233333
# max       4.000000     2.663861          0.529181

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.35556817, -0.28781206, -2.00607592,  0.67982728],
#        [-0.04526917, -0.28360391, -1.04441078,  0.07710735],
#        [-0.36040237, -0.23443505,  0.43568836, -0.79673901],
#        ...,
#        [-0.32174002, -0.24905282, -0.53928702,  0.01176393],
#        [ 0.46490226, -0.16968866,  0.77909266,  0.27216235],
#        [-0.54906004,  2.43567054, -1.43706298, -0.23888173]])

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_k = classifier.predict(x_test)
print(np.concatenate((y_pred_k.reshape(len(y_pred),1), y_test.values.reshape(len(y_test),1)),1))
# Out:
# [[4 4]
#  [4 4]
#  [4 4]
#  ...
#  [1 1]
#  [3 3]
#  [3 3]]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_k)
print(cm)
names = ['SH', 'UN', 'SS', 'CB']

cf=sns.heatmap(cm, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=names,yticklabels=names)
plt.show()
accuracy_score(y_test, y_pred_k)
# Out:
# [[262   3   6   1]
#  [ 13  15   5   2]
#  [  3   8 221  36]
#  [  1   7  54 336]]
# 0.8571428571428571

# %%
well_13.head()
# Out:
#         Well       GR      RT    RHOB    NPHI
# Depth
# 4175.5    13  20.6032  4.1812  2.6117  0.0770
# 4176.0    13  21.4990  4.5516  2.6131  0.0798
# 4176.5    13  22.4472  4.4804  2.6334  0.0801
# 4177.0    13  29.6713  4.3859  2.6328  0.1005
# 4177.5    13  34.7014  4.8566  2.6183  0.1001

# %%
well_13.columns
# Out:
# Index(['Well', 'GR', 'RT', 'RHOB', 'NPHI'], dtype='object')

# %%
Well_13_x_sc=sc.transform(well_13.drop("Well",axis=1))

# %%
well_13["facies_pred"]=classifier.predict(Well_13_x_sc)

# %%
well_13["facies_pred"].replace(1,"SH",inplace=True)
well_13["facies_pred"].replace(2,"UN",inplace=True)
well_13["facies_pred"].replace(3,"SS",inplace=True)
well_13["facies_pred"].replace(4,"CB",inplace=True)

# %%
submission=pd.read_excel('VolveData_Project.xlsx', sheet_name='well 13',index_col=0)
submission=well_13

# %%
well_13
# Out:
#         Well       GR      RT    RHOB    NPHI facies_pred
# Depth
# 4175.5    13  20.6032  4.1812  2.6117  0.0770          CB
# 4176.0    13  21.4990  4.5516  2.6131  0.0798          CB
# 4176.5    13  22.4472  4.4804  2.6334  0.0801          CB
# 4177.0    13  29.6713  4.3859  2.6328  0.1005          CB
# 4177.5    13  34.7014  4.8566  2.6183  0.1001          CB
# ...      ...      ...     ...     ...     ...         ...
# 4586.5    13  68.1668  1.3877  2.5219  0.1587          CB
# 4587.0    13  71.9559  1.3800  2.5062  0.1739          SH
# 4587.5    13  67.5752  1.3391  2.5030  0.1704          SS
# 4588.0    13  65.0492  1.3286  2.4855  0.1754          SS
# 4588.5    13  56.5963  1.3268  2.4657  0.1725          CB
#
# [827 rows x 6 columns]

# %%
pd.DataFrame(well_13,columns=well_13.columns).to_csv("logistic_facies_pred1.csv")
